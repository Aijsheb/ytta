# %% [markdown]
# <a href="https://colab.research.google.com/github/Aijsheb/ytta/blob/main/NovaldoArisGunawan_G.211.22.0020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Support Vector Machine
# Importing the Iibraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the datasets
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5ad3a999-2fe9-43a0-9610-4eebac031026" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ad3a999-2fe9-43a0-9610-4eebac031026">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pandas.core.common import random_state
datasets = pd.read_csv('')
X = dataset.iloc[:, [2,3]].values
Y = datasets.iloc[:,4].values

#Splitting the datasets into Training set and Test set

from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y,test_size = 0.25, random_state =0)

# Freature Scaling

from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_Train = sc_X.fit_transform(X_Train)
X_Test = sc_X.transform(X_Test)

from sklearn.svm import svs
classifier = SVC(karel = 'linear', random_state =0)
classifier.fit(X_Train, Y_Train)

# Prwditing the test set result

Y_Pred = classifier.predict(X_Test)

# Making the Confusion Matrix

from sklearn.metrics import  confusion_matrix
cm = confusion_matrix(Y_Test, Y_Pred)

# Visualising the Training set result

from matplotlib.color import ListedColormap
X_Set, Y_Set = X_train, Y_Train
X1, X2 = np.meshgrid(np.arange(start = X_Set[:, 0].min()- 1, stop =X_Set[:, 0].max()+ 1, step = 0.01),np.arange(start = X_Set[:, 1]
                        .min() - 1, stop = X_Set[:,1].max() + 1, step = 0.01))
pit.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
pit.xlim(X1,min(), x1.max())
pit.ylim(x2.min(), X2.max())
for i, j in enumerate(np.unique(Y_Set)):
    pit.scatter(X_Set[Y_Set == j, 0], X_Set[Y_Set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
pit.title('Support Vector Machine (Training set)')
pit.xlabel('Age')
pit.ylabel('Estimated Salary')
pit.legend()
pit.show()

# Visualising the Test set results

from matplotlib.colors import ListedColormap
X_Set, Y_Set = X_Test, Y_Test
X1, X2 = np.meshgrid(np.arange(start = X_Set[:, 0].min() - 1, stop = X_Set[:, 0].max() + 1, step = 0.01),
                     np.arange(start =X_set[: 1].min() - 1, stop =X_Set[:, 1].max() + 1, step = 0.01))
pit.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
pit.xlim(X1.min(), X1.max())
pit.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(Y_Set)):
    pit.scatter(X_Set[Y_Set == j, 0], X_Set[Y_Set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
pit.title('Support Vector Machine (Test set)')
pit.xlabel('Age')
pit.ylabel('Estimated Salary')
pit.legend()
pit.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-92ddf0f43a3e> in <cell line: 3>()
#       1 from pandas.core.common import random_state
#       2 datasets = ('Sosial_Netw/Users/gunawan/Downloads/Social_Network_Ads.csvork_Ads.csv')
# ----> 3 X = dataset.iloc[:, [2,3]].values
#       4 Y = datasets.iloc[:,4].values
#       5
#
# NameError: name 'dataset' is not defined
